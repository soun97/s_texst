# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
db_connection_path = 'mysql+pymysql://[db유저이름]:[db password]@[host address]/[db name]'
db_connection = create_engine(db_connection_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 db_connection_path = 'mysql+pymysql://[db유저이름]:[db password]@[host address]/[db name]'
# ----> 2 db_connection = create_engine(db_connection_path)
#
# NameError: name 'create_engine' is not defined

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db_connection_path = 'mysql+pymysql://root:thdns^^04@127.0.0.1/stock_data'
engine = create_engine(db_connection_path)

# %%
df
# Out:
#      Unnamed: 0      종목코드    시가    종가          일자       종목명    시장구분  증권구분  \
# 0          1502  900080.0  2010  1895  2015-05-04  에스앤씨엔진그룹  KOSDAQ  외국주권
# 1          1503  900080.0  2270  2100  2015-04-30  에스앤씨엔진그룹  KOSDAQ  외국주권
# 2          1504  900080.0  1900  2255  2015-04-29  에스앤씨엔진그룹  KOSDAQ  외국주권
# 3          1505  900080.0  1770  1965  2015-04-28  에스앤씨엔진그룹  KOSDAQ  외국주권
# 4          1506  900080.0  1715  1745  2015-04-27  에스앤씨엔진그룹  KOSDAQ  외국주권
# ..          ...       ...   ...   ...         ...       ...     ...   ...
# 121         639  134780.0  6840  6720  2017-11-22        화진  KOSDAQ    주권
# 122         640  134780.0  6620  6840  2017-11-21        화진  KOSDAQ    주권
# 123         641  134780.0  6830  6640  2017-11-20        화진  KOSDAQ    주권
# 124         642  134780.0  7440  6830  2017-11-17        화진  KOSDAQ    주권
# 125         643  134780.0  6700  7410  2017-11-16        화진  KOSDAQ    주권
#
#         대비    등락률      고가      저가        거래량          거래대금          시가총액  \
# ...

# %%
df = pd.read_csv("append2023-10-24DELIST.csv", encoding="cp949")

# %%
df.head(3)
# Out:
#    Unnamed: 0      종목코드    시가    종가          일자       종목명    시장구분  증권구분  \
# 0        1502  900080.0  2010  1895  2015-05-04  에스앤씨엔진그룹  KOSDAQ  외국주권
# 1        1503  900080.0  2270  2100  2015-04-30  에스앤씨엔진그룹  KOSDAQ  외국주권
# 2        1504  900080.0  1900  2255  2015-04-29  에스앤씨엔진그룹  KOSDAQ  외국주권
#
#       대비    등락률      고가      저가        거래량          거래대금          시가총액  \
# 0 -205.0  -9.76  2080.0  1890.0  1080725.0  2.101953e+09  8.102242e+10
# 1 -155.0  -6.87  2365.0  2010.0  3852653.0  8.405506e+09  8.978737e+10
# 2  290.0  14.76  2255.0  1855.0  2182228.0  4.581735e+09  9.641454e+10
#
#    Unnamed: 3  상장주식수
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN

# %%
df.to_sql("test", engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5860\2643504405.py in <module>
# ----> 1 df.to_sql("test", engine)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# ...

# %%
pd.read_pickle("D:/soun_pycharm/DELIST/pickle/000030.csv.pkl")
# Out:
#               일자  종목코드   종목명   시장구분 증권구분     종가   대비   등락률     시가     고가  \
# 0     2019/02/12    30  우리은행  KOSPI   주권  14800    0  0.00      0      0
# 1     2019/02/11    30  우리은행  KOSPI   주권  14800    0  0.00      0      0
# 2     2019/02/08    30  우리은행  KOSPI   주권  14800    0  0.00      0      0
# 3     2019/02/07    30  우리은행  KOSPI   주권  14800    0  0.00      0      0
# 4     2019/02/01    30  우리은행  KOSPI   주권  14800    0  0.00      0      0
# ...          ...   ...   ...    ...  ...    ...  ...   ...    ...    ...
# 1003  2015/01/08    30  우리은행  KOSPI   주권   9530  130  1.38   9420   9620
# 1004  2015/01/07    30  우리은행  KOSPI   주권   9400  -40 -0.42   9380   9510
# 1005  2015/01/06    30  우리은행  KOSPI   주권   9440 -190 -1.97   9520   9580
# 1006  2015/01/05    30  우리은행  KOSPI   주권   9630 -160 -1.63   9750   9760
# 1007  2015/01/02    30  우리은행  KOSPI   주권   9790 -210 -2.10  10000  10000
#
#         저가      거래량         거래대금            시가총액
# ...

# %%
delist_df = pd.DataFrame()

# %%
import os

folder="D:/soun_pycharm/DELIST/pickle"
namelist=os.listdir("D:/soun_pycharm/DELIST/pickle")

# %%
for name in namelist:
    df=pd.read_pickle(f'{folder}/{name}')
   # df["종목코드"] = df.iloc[0]["종목코드"]
    delist_df=pd.concat([df,delist_df], axis=1)

# %%
import os

folder ='C:/Users/soun/Documents/kiwoom_test/original'
namelist=os.listdir(folder)

# %%
namelist
# Out:
# ['000020.xlsx',
#  '000040.xlsx',
#  '000050.xlsx',
#  '000070.xlsx',
#  '000075.xlsx',
#  '000080.xlsx',
#  '000087.xlsx',
#  '000100.xlsx',
#  '000105.xlsx',
#  '000120.xlsx',
#  '000140.xlsx',
#  '000145.xlsx',
#  '000150.xlsx',
#  '000155.xlsx',
#  '000157.xlsx',
#  '000180.xlsx',
#  '000210.xlsx',
#  '000215.xlsx',
#  '000220.xlsx',
#  '000225.xlsx',
#  '000227.xlsx',
#  '000230.xlsx',
#  '000240.xlsx',
#  '000270.xlsx',
#  '000300.xlsx',
#  '000320.xlsx',
#  '000325.xlsx',
#  '000370.xlsx',
#  '000390.xlsx',
#  '000400.xlsx',
#  '000430.xlsx',
#  '000480.xlsx',
#  '000490.xlsx',
#  '000500.xlsx',
#  '000520.xlsx',
#  '000540.xlsx',
#  '000545.xlsx',
#  '000590.xlsx',
#  '000640.xlsx',
#  '000650.xlsx',
#  '000660.xlsx',
#  '000670.xlsx',
#  '000680.xlsx',
#  '000700.xlsx',
#  '000720.xlsx',
#  '000725.xlsx',
#  '000760.xlsx',
#  '000810.xlsx',
#  '000815.xlsx',
#  '000850.xlsx',
#  '000860.xlsx',
#  '000880.xlsx',
#  '000885.xlsx',
#  '00088K.xlsx',
#  '000890.xlsx',
# ...

# %%
import pandas as pd

original_df=pd.DataFrame()

# %%
for name in namelist:
    df=pd.read_excel(f'{folder}/{name}')
    original_df=pd.concat([df,original_df], axis=1)

# %%
original_df.head(5)
# Out:
#    Unnamed: 0    종목코드     현재가     거래량    거래대금        일자      시가      고가  \
# 0           0  5380.0  190000  503562   95759  20240104  192000  192800
# 1           1     NaN  193800  548675  107386  20240103  199100  199500
# 2           2     NaN  200500  373050   74806  20240102  202000  202500
# 3           3     NaN  203500  766503  154696  20231228  198800  203500
# 4           4     NaN  198500  331186   65619  20231227  198700  199300
#
#        저가  수정주가구분  ...     시가     고가     저가  수정주가구분  수정비율  대업종구분  소업종구분  종목정보  \
# 0  189100     NaN  ...  10500  10600  10340     NaN   NaN    NaN    NaN   NaN
# 1  193800     NaN  ...  10410  10580  10350     NaN   NaN    NaN    NaN   NaN
# 2  199800     NaN  ...  10270  10580  10270     NaN   NaN    NaN    NaN   NaN
# 3  198400     NaN  ...   9930  10270   9910     NaN   NaN    NaN    NaN   NaN
# 4  197200     4.0  ...   9890  10030   9800     4.0   0.0    NaN    NaN   NaN
#
#    수정주가이벤트  전일종가
# 0      NaN   NaN
# 1      NaN   NaN
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db_connection_path = 'mysql+pymysql://root:thdns^^04@127.0.0.1/stock_data'
engine = create_engine(db_connection_path)

# %%
import os

folder ='C:/Users/soun/Documents/kiwoom_test/original'
namelist=os.listdir(folder)

# %%
original_df=pd.DataFrame()

# %%
for name in namelist:
    df=pd.read_excel(f'{folder}/{name}')
    original_df=pd.concat([df,original_df],axis=0)

# %%
original_df
# Out:
#      Unnamed: 0    종목코드     현재가     거래량    거래대금        일자      시가      고가  \
# 0             0  5380.0  190000  503562   95759  20240104  192000  192800
# 1             1     NaN  193800  548675  107386  20240103  199100  199500
# 2             2     NaN  200500  373050   74806  20240102  202000  202500
# 3             3     NaN  203500  766503  154696  20231228  198800  203500
# 4             4     NaN  198500  331186   65619  20231227  198700  199300
# ..          ...     ...     ...     ...     ...       ...     ...     ...
# 595         595     NaN   15300  487257    7348  20210803   14650   15350
# 596         596     NaN   14650   86857    1272  20210802   14700   14800
# 597         597     NaN   14650  115604    1681  20210730   14650   14750
# 598         598     NaN   14600   83468    1216  20210729   14500   14650
# 599         599     NaN   14450   94912    1369  20210728   14300   14600
#
#          저가  수정주가구분  수정비율  대업종구분  소업종구분  종목정보  수정주가이벤트  전일종가
# ...

# %%
original_df.to_sql("original_db", engine)
# Out:
# 326400

# %%
# !pip install pymysql

# %%
import pymysql

# %%
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='thdns^^04', db='stock_data', charset='utf8')

# %%
cursor = db.cursor()

# %%
cursor.execute("SELECT * FROM original_db limit 10")
rs = cursor.fetchall()

# %%
for r in rs:
    print(r)
# Out:
# (0, 0, '5380', 190000, 503562, 95759, 20240104, 192000, 192800, 189100, None, None, None, None, None, None, None)
# (1, 1, None, 193800, 548675, 107386, 20240103, 199100, 199500, 193800, None, None, None, None, None, None, None)
# (2, 2, None, 200500, 373050, 74806, 20240102, 202000, 202500, 199800, None, None, None, None, None, None, None)
# (3, 3, None, 203500, 766503, 154696, 20231228, 198800, 203500, 198400, None, None, None, None, None, None, None)
# (4, 4, None, 198500, 331186, 65619, 20231227, 198700, 199300, 197200, 4.0, 0.0, None, None, None, None, None)
# (5, 5, None, 198800, 409928, 81491, 20231226, 200500, 200500, 197700, None, None, None, None, None, None, None)
# (6, 6, None, 199000, 347866, 69334, 20231222, 200000, 200500, 198500, None, None, None, None, None, None, None)
# (7, 7, None, 198700, 545031, 108228, 20231221, 197500, 202000, 197100, None, None, None, None, None, None, None)
# ...

# %%
no = 3
name = "test"
code = "005390"
date = "2024-01-01"
reason = "aaa"
etc = "abc"

query = f"""
    INSERT INTO `stock_data`.`delist_db` (
        `no`, `name`, `code`, `delist_date`, `reason`, `etc`
    ) VALUES (
        {no}, '{name}', '{code}', '{date}', '{reason}', '{etc}'
    )
"""

cursor.execute(query)
# Out:
# 1

# %%
db.commit()
